# %% [markdown]
# # Interactive Sales Dashboard
# This notebook demonstrates the sales analysis using Seaborn and Plotly.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
from data_preparation import load_and_prepare_data
from visualizations.seaborn_plots import *
from visualizations.plotly_interactive import *

# %% [markdown]
# ## 1. Data Preparation

# %%
df = load_and_prepare_data()
set_style()
df.head()

# %% [markdown]
# ## 2. Seaborn Statistical Visualizations

# %%
plot_sales_trend(df)
plt.show()

# %%
plot_product_performance(df)
plt.show()

# %%
plot_customer_segmentation(df)
plt.show()

# %%
plot_price_vs_quantity(df)
plt.show()

# %%
plot_correlation_heatmap(df)
plt.show()

# %% [markdown]
# ## 3. Interactive Plotly Visualizations

# %%
plotly_sales_trend(df)

# %%
plotly_product_performance(df)

# %%
plotly_customer_segmentation(df)

# %%
plotly_regional_distribution(df)

# %%
plotly_price_vs_quantity(df)
